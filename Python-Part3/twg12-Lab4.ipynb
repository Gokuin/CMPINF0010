# %% [markdown]
# # Lab Exercises
#
# ## Introduction to Python, Part 3
#
# ### Questions/Office Hours
#
# If you have questions about this week's lab **ANY** TA for this class can help you with any problems in office hours. That being said, if you need help over email it is best to email **YOUR** TA.
#
# You can also always ask the instructor for help with skills labs (even though they are not covered in lecture). You can email the instructor of come to his office hours.

# %% [markdown]
# ----

# %% [markdown]
# ## Exercises
#
# The exercises this week deal with some features that we haven't otherwise covered. There are links to specific parts of the Python for Everyone book in each question, but here's a more general reference:
#
# * [Chapter 7: Files](https://www.py4e.com/html3/07-files)
# * [Chapter 8: Lists](https://www.py4e.com/html3/08-lists)
# * [Chapter 9: Dictionaries](https://www.py4e.com/html3/09-dictionaries)
#
# ### A Note on Boilerplate
#
# One of the major benefits of tools like Jupyter are that it makes it easy to strip away the "boilerplate" that comes with programming languages; some of these exercises relies on a little bit more of that than in weeks past. If you get confused or something stops working, email your TA or come to ofice hours.

# %% [markdown]
# ----

# %% [markdown]
# #### **Exercise 1**
#
# ###### sections to reference: [opening files](https://www.py4e.com/html3/07-files)
#
# This one definitely falls in the category of "pointless exercises". You're going to make a program that prompts for a filename. If the file exists, quit the program! Don't print anything out, don't do anything with the file, don't do anything. Just quit. If the file *doesn't* exist, complain, and prompt the user for a filename again. Do this until the user gives you a valid filename or pours water on their computer in frustration. (Just kidding. Don't pour water on your computer.)
#
# You're going to want to put the filename prompt inside a loop, so you can ask the user for a filename as many times as you want. But what kind of loop? And how will you get out of the loop once you've got a valid file?
#
# ![thinking face](https://media.giphy.com/media/3o7buirYcmV5nSwIRW/giphy.gif)

# %%
import os.path
from os import path

notvalid = True
while(notvalid):
    fn = input(prompt="Enter in a file name: ")
    if path.isfile(fn):
        notvalid = False
# Out:
# Enter in a file name: C:\Users\tatty\Downloads\c2w2.pdf

# %% [markdown]
# #### **Exercise 2**
#
# ###### sections to reference: [opening files](https://www.py4e.com/html3/07-files)
#
# Write a program that asks the user for a file and simply prints the entire contents of the file out. If the user enters a file that doesn't exist, give the user an error and prompt for a filename again.
#
# **Hint**: You can do the printing in *one line of code*.

# %%
notvalid = True
while(notvalid):
    fn = input(prompt="Enter in a file path to a file to have it file contents printed out: ")
    if path.isfile(fn):
        notvalid = False
#path is valid now we want to print its contents out
#open the file and store it contents
contents = open(fn)
#get all the lines of the file read in
allLines = contents.readlines()
#iterate over all the lines and print them out
for line in allLines:
    print(line)
# Out:
# Enter in a file path to a file to have it file contents printed out: C:\Users\tatty\Downloads\test.txt.txt
# test1
#
# test2 test3
#
# test4

# %% [markdown]
# #### **Exercise 3**
#
# ###### sections to reference: [parsing strings](https://www.py4e.com/html3/06-strings)
#
# This exercise deals with a test file, `spam1.txt`. You can open that file in a new tab so you can get a sense for what it looks like and what you're going to be dealing with.
#
# You're going to be writing a program that deals with a list of spam confidence values. The file, spam1.txt, looks something like this:

# %% [raw]
# X-DSPAM-Confidence: 0.8475
# X-DSPAM-Confidence: 0.9288
# X-DSPAM-Confidence: 0.0129
# X-DSPAM-Confidence: 0.5102
# X-DSPAM-Confidence: 0.8912
# ...

# %% [markdown]
# There are 500 spam confidence values in the file `spam1.txt`. I want you to tell me two things about the values:
#
# 1. The **average** of all of the spam values in the file, and
# 1. **How many** emails have a spam value of over 95% (so, >0.95).
#
# You'll need to read the file line by line and process each line so you can get the float.
#
# After you're done with that program, make a Markdown cell below your code and **tell me**, in a few sentences, what the average spam confidence *means*. By way of explanation, the spam value is a value generated by an algorithm (individual email providers keep their algorithms closely guarded, but they're all pretty much based on *Bayesian math*, if you're interested.) That algorithm rates any given email from 0 to 1 on how confident they are that the email is spam. 1 means that the algorithm thinks it *definitely* is spam, and 0 means that the algorithm thinks there's no chance it's spam.
#
# So, once you have your average value, **what does that mean** for any given email in the set? What are the chances it'll be spam or not?

# %%
spam1 = open("C:/Users/tatty/0010Github/Python-Part3/spam1.txt")
EO95 = 0
numOfValues = 0
totalOfValues = 0
#get all the lines of the file read in
allLines = spam1.readlines()
#iterate over all the lines and print them out
for line in allLines:
    splitNum = line.split(":")[1]
    splitNum = float(splitNum)
    if(splitNum > .95):
        EO95+=1
    totalOfValues += float(splitNum)
    numOfValues +=1
print("Analysis of spam1.txt:\n")
print("Emails with a spam value over 95%: ", EO95)
print("Percent of emails with a value over 95%: ", (EO95 / numOfValues) * 100,"%")
print("Number of values in the file: ", numOfValues)
print("Total of all the values in the file:", totalOfValues)
print("Avg spam confidence of spam1.txt: ", totalOfValues / numOfValues)
# Out:
# Analysis of spam1.txt:
#
# Emails with a spam value over 95%:  68
# Percent of emails with a value over 95%:  13.600000000000001 %
# Number of values in the file:  500
# Total of all the values in the file: 375.3995999999997
# Avg spam confidence of spam1.txt:  0.7507991999999993

# %% [markdown]
# Analysis of spam1.txt:
#
# Emails with a spam value over 95%:  68
# Percent of emails with a value over 95%:  13.600000000000001 %
# Number of values in the file:  500
# Total of all the values in the file: 375.3995999999997
# Avg spam confidence of spam1.txt:  0.7507991999999993
# # What the values mean
# With a avg spam confidence of spam1.txt data we see a value of 0.75079 or 0.7508 / 0.100. This means that over two thirds of the emails had a spam confidence value of atleast 0.75079. The spam confidence value is a rating of how confident the algorithm is that the email is spam. So over all in the spam1 we see a good amount of spam. IE you have a 3/4 chance of opening spam for every email that exists in this set.

# %% [markdown]
# #### **Exercise 4**
#
# ###### sections to reference: [searching through a file](https://www.py4e.com/html3/07-files)
#
# This exercise is a continuation of the previous one. You've got a new text file to process, called `spam2.txt`. It has a bunch of spam confidence values, but it's also got some other information, too, like the sender, message subject, and the date and time that it's been sent. A sample record from the file looks like this:

# %% [raw]
# From louis@media.berkeley.edu Fri Jan 4 18:10:48 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# X-Sieve: CMU Sieve 2.3
# Message-ID: <200801042308.m04N8v6O008125@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Date: Fri 4 Jan 2008 18:08:57 -0500
# To: source@collab.sakaiproject.org
# Subject: [sakai] svn commit: r39771 - in bspace/site-manage/sakai_2-4-x/site-manage-tool/tool/src: bundle java/org/sakaiproject/site/tool
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 18:10:48 2008
# X-DSPAM-Confidence: 0.6178
# X-DSPAM-Probability: 0.0000

# %% [markdown]
# There is a lot of information here, and this, if you can believe it, is a *stripped-down* version of what the email server records look like.
#
# `spam2.txt` contains a bunch of email records. You're going to write a program, similar to Exercise 3, wherein you grab the spam confidence from each email. Like before, you're going to **take the average** of these values. When you encounter an email with a spam confidence greater than 95%, though, you're going to **print out** the email address that sent the email, the email address that received it, the date and time that it was sent, and the spam confidence value.
#
# **Note**: Don't simply print out the entire lines of the file that have that information; get the specific items that you want and format it nicely.

# %%
spam2 = open("C:/Users/tatty/0010Github/Python-Part3/spam2.txt")
EO95 = 1
numOfValues = 1
totalOfValues = 0
#get all the lines of the file read in
allLines = spam2.readlines()
#iterate over all the lines and print them out
for line in allLines:
    #print("Current Line: ", line)
    if "From" in line:
        From = line
        #print("From line: ",From)
    elif "To:" in line:
        to = line
        #print("To line: ", to)
    elif "Date:" in line:
        date = line
        #print("Date: ",date)
    elif "X-DSPAM-Confidence:" in line:
        splitNum = line.split(":")[1]
        #print("Confidence value: ", splitNum)
        splitNum = float(splitNum)
        totalOfValues += float(splitNum)
        numOfValues +=1
        if(splitNum > .95):
            EO95+=1
            print("----------------------------------------------------------------------------------------------")
            print("High Confidence value found:\n"+ From+"\n"+to,"\n"+date,"\nXSConfidence Val: ",splitNum,"\n")
            print("----------------------------------------------------------------------------------------------")
        
print("Analysis of spam2.txt:\n")
print("----------------------------------------------------------------------------------------------")
print("Emails with a spam value over 95%: ", EO95)
print("Percent of emails with a value over 95%: ", (EO95 / numOfValues) * 100,"%")
print("Number of values in the file: ", numOfValues)
print("Total of all the values in the file:", totalOfValues)
print("Avg spam confidence of spam2.txt: ", totalOfValues / numOfValues)
print("Percent Avg spam confidence of spam2.txt:", (totalOfValues / numOfValues) * 100,"%")
print("----------------------------------------------------------------------------------------------")

#NOTES:
#Analysis of spam2.txt:
#----------------------------------------------------------------------------------------------
#Emails with a spam value over 95%:  1003
#Percent of emails with a value over 95%:  55.784204671857616 %
#Number of values in the file:  1798
#Total of all the values in the file: 1606.7480999999987
#Avg spam confidence of spam2.txt:  0.8936307563959948
#Percent Avg spam confidence of spam2.txt: 89.36307563959947 %
#----------------------------------------------------------------------------------------------
# Out:
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 16:33:03 -0500
#
# XSConfidence Val:  0.9846
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 16:22:15 -0500
#
# XSConfidence Val:  0.9907
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 15:25:57 -0500
#
# XSConfidence Val:  0.9895
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 15:24:11 -0500
#
# XSConfidence Val:  0.9965
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 15:22:15 -0500
#
# XSConfidence Val:  0.9875
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 14:30:46 -0500
#
# XSConfidence Val:  0.9867
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 13:49:37 -0500
#
# XSConfidence Val:  0.9903
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 13:19:10 -0500
#
# XSConfidence Val:  0.9907
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 13:15:37 -0500
#
# XSConfidence Val:  0.9886
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 13:06:42 -0500
#
# XSConfidence Val:  0.9875
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 13:04:47 -0500
#
# XSConfidence Val:  0.9854
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 12:30:40 -0500
#
# XSConfidence Val:  0.9877
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 12:26:30 -0500
#
# XSConfidence Val:  0.9881
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 12:23:18 -0500
#
# XSConfidence Val:  0.9864
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 11:43:01 -0500
#
# XSConfidence Val:  0.987
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: gopal.ramasammycook@gmail.com
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 11:10:46 -0500
#
# XSConfidence Val:  0.9837
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: gsilver@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 10:26:43 -0500
#
# XSConfidence Val:  0.9852
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: stuart.freeman@et.gatech.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 10:21:33 -0500
#
# XSConfidence Val:  0.9928
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 10:19:54 -0500
#
# XSConfidence Val:  0.9898
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: gsilver@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 10:06:12 -0500
#
# XSConfidence Val:  0.9855
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: gsilver@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 10:03:38 -0500
#
# XSConfidence Val:  0.9856
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 10:01:01 -0500
#
# XSConfidence Val:  0.9892
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: wagnermr@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 09:12:14 -0500
#
# XSConfidence Val:  0.9879
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: gopal.ramasammycook@gmail.com
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 3 Jan 2008 08:42:40 -0500
#
# XSConfidence Val:  0.9843
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: wagnermr@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 17:01:05 -0500
#
# XSConfidence Val:  0.9871
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: stuart.freeman@et.gatech.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 16:52:23 -0500
#
# XSConfidence Val:  0.9947
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 15:50:13 -0500
#
# XSConfidence Val:  0.9832
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 15:18:59 -0500
#
# XSConfidence Val:  0.9864
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 14:34:07 -0500
#
# XSConfidence Val:  0.9842
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 11:12:00 -0500
#
# XSConfidence Val:  0.986
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 11:08:05 -0500
#
# XSConfidence Val:  0.9842
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 09:39:09 -0500
#
# XSConfidence Val:  0.9865
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: aaronz@vt.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 09:10:36 -0500
#
# XSConfidence Val:  0.9865
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 09:06:18 -0500
#
# XSConfidence Val:  0.9852
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 08:53:30 -0500
#
# XSConfidence Val:  0.9856
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: gopal.ramasammycook@gmail.com
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 06:59:39 -0500
#
# XSConfidence Val:  0.9843
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 03:02:55 -0500
#
# XSConfidence Val:  0.9844
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 2 Jan 2008 02:51:47 -0500
#
# XSConfidence Val:  0.9823
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 31 Dec 2007 16:27:25 -0500
#
# XSConfidence Val:  0.9872
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 31 Dec 2007 14:55:49 -0500
#
# XSConfidence Val:  0.9897
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 31 Dec 2007 14:51:25 -0500
#
# XSConfidence Val:  0.9887
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 31 Dec 2007 14:40:55 -0500
#
# XSConfidence Val:  0.9866
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: wagnermr@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 31 Dec 2007 09:02:22 -0500
#
# XSConfidence Val:  0.9847
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: csev@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Sun, 30 Dec 2007 16:46:31 -0500
#
# XSConfidence Val:  0.983
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Sun, 30 Dec 2007 13:32:36 -0500
#
# XSConfidence Val:  0.9779
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: ian@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Sat, 29 Dec 2007 14:47:31 -0500
#
# XSConfidence Val:  0.9852
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 27 Dec 2007 21:22:33 -0500
#
# XSConfidence Val:  0.9865
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: knoop@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 27 Dec 2007 17:53:54 -0500
#
# XSConfidence Val:  0.9776
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: knoop@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 27 Dec 2007 17:53:24 -0500
#
# XSConfidence Val:  0.9776
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: knoop@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 27 Dec 2007 17:52:45 -0500
#
# XSConfidence Val:  0.9797
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: knoop@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 27 Dec 2007 17:51:38 -0500
#
# XSConfidence Val:  0.9776
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: knoop@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 27 Dec 2007 17:50:57 -0500
#
# XSConfidence Val:  0.9793
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 27 Dec 2007 13:46:21 -0500
#
# XSConfidence Val:  0.9857
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: jimeng@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 27 Dec 2007 10:22:01 -0500
#
# XSConfidence Val:  0.9857
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: csev@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 27 Dec 2007 10:09:56 -0500
#
# XSConfidence Val:  0.9863
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: jimeng@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 26 Dec 2007 11:38:56 -0500
#
# XSConfidence Val:  0.9881
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: stephen.marquard@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 24 Dec 2007 02:05:26 -0500
#
# XSConfidence Val:  0.9812
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: ian@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Sun, 23 Dec 2007 12:51:47 -0500
#
# XSConfidence Val:  0.9832
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: jimeng@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Sat, 22 Dec 2007 12:06:15 -0500
#
# XSConfidence Val:  0.9885
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: jimeng@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Sat, 22 Dec 2007 11:57:40 -0500
#
# XSConfidence Val:  0.9854
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: stuart.freeman@et.gatech.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 15:48:56 -0500
#
# XSConfidence Val:  0.9869
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 14:37:15 -0500
#
# XSConfidence Val:  0.9866
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 12:19:40 -0500
#
# XSConfidence Val:  0.9877
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: bkirschn@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 11:49:20 -0500
#
# XSConfidence Val:  0.9872
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 10:04:05 -0500
#
# XSConfidence Val:  0.9834
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 10:02:26 -0500
#
# XSConfidence Val:  0.9856
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: bkirschn@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 09:54:18 -0500
#
# XSConfidence Val:  0.9859
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: bkirschn@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 09:54:07 -0500
#
# XSConfidence Val:  0.987
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 09:53:18 -0500
#
# XSConfidence Val:  0.9848
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 09:49:44 -0500
#
# XSConfidence Val:  0.9836
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 09:43:21 -0500
#
# XSConfidence Val:  0.9892
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 09:33:08 -0500
#
# XSConfidence Val:  0.9894
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 09:08:40 -0500
#
# XSConfidence Val:  0.9816
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: stephen.marquard@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 09:07:21 -0500
#
# XSConfidence Val:  0.9858
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: bkirschn@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 09:01:05 -0500
#
# XSConfidence Val:  0.9879
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 08:42:38 -0500
#
# XSConfidence Val:  0.9836
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 08:41:08 -0500
#
# XSConfidence Val:  0.9845
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 06:29:07 -0500
#
# XSConfidence Val:  0.9907
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 06:16:13 -0500
#
# XSConfidence Val:  0.9883
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 06:11:34 -0500
#
# XSConfidence Val:  0.9874
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 06:00:08 -0500
#
# XSConfidence Val:  0.9843
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 03:31:10 -0500
#
# XSConfidence Val:  0.9831
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 21 Dec 2007 03:19:18 -0500
#
# XSConfidence Val:  0.982
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: dlhaines@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 22:37:45 -0500
#
# XSConfidence Val:  0.9851
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: dlhaines@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 22:15:37 -0500
#
# XSConfidence Val:  0.9859
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: dlhaines@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 22:14:51 -0500
#
# XSConfidence Val:  0.984
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: dlhaines@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 22:12:22 -0500
#
# XSConfidence Val:  0.9817
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: hu2@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 21:26:30 -0500
#
# XSConfidence Val:  0.9829
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: bkirschn@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 18:36:59 -0500
#
# XSConfidence Val:  0.9838
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: josrodri@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 18:13:19 -0500
#
# XSConfidence Val:  0.9816
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 16:48:47 -0500
#
# XSConfidence Val:  0.9829
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 16:33:26 -0500
#
# XSConfidence Val:  0.9776
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 16:30:09 -0500
#
# XSConfidence Val:  0.9762
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 16:31:55 -0500
#
# XSConfidence Val:  0.9799
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 16:28:29 -0500
#
# XSConfidence Val:  0.9812
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: josrodri@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 16:25:18 -0500
#
# XSConfidence Val:  0.9804
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 14:08:17 -0500
#
# XSConfidence Val:  0.9804
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: tnguyen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 13:37:50 -0500
#
# XSConfidence Val:  0.9796
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 13:12:59 -0500
#
# XSConfidence Val:  0.978
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: arwhyte@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 11:32:15 -0500
#
# XSConfidence Val:  0.9861
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 11:20:45 -0500
#
# XSConfidence Val:  0.9799
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 10:44:49 -0500
#
# XSConfidence Val:  0.9812
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 10:33:40 -0500
#
# XSConfidence Val:  0.9808
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 10:28:59 -0500
#
# XSConfidence Val:  0.9799
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 10:13:54 -0500
#
# XSConfidence Val:  0.9832
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 10:00:44 -0500
#
# XSConfidence Val:  0.9758
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: josrodri@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:58:50 -0500
#
# XSConfidence Val:  0.9842
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:44:18 -0500
#
# XSConfidence Val:  0.977
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:43:48 -0500
#
# XSConfidence Val:  0.9776
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:43:26 -0500
#
# XSConfidence Val:  0.9794
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:43:05 -0500
#
# XSConfidence Val:  0.9785
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:40:27 -0500
#
# XSConfidence Val:  0.9773
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:40:05 -0500
#
# XSConfidence Val:  0.9785
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:39:35 -0500
#
# XSConfidence Val:  0.9813
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:39:13 -0500
#
# XSConfidence Val:  0.9785
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:38:31 -0500
#
# XSConfidence Val:  0.9774
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:37:35 -0500
#
# XSConfidence Val:  0.9779
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:37:17 -0500
#
# XSConfidence Val:  0.9789
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:23:10 -0500
#
# XSConfidence Val:  0.9787
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:22:11 -0500
#
# XSConfidence Val:  0.9777
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:10:31 -0500
#
# XSConfidence Val:  0.9787
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: sgithens@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 09:04:19 -0500
#
# XSConfidence Val:  0.9851
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 07:59:02 -0500
#
# XSConfidence Val:  0.9889
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: dlhaines@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 07:38:05 -0500
#
# XSConfidence Val:  0.9839
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: stephen.marquard@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 04:22:05 -0500
#
# XSConfidence Val:  0.9844
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: stephen.marquard@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 04:18:47 -0500
#
# XSConfidence Val:  0.9834
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 04:13:01 -0500
#
# XSConfidence Val:  0.9819
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: david.horwitz@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 20 Dec 2007 03:58:17 -0500
#
# XSConfidence Val:  0.9843
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 19 Dec 2007 22:23:37 -0500
#
# XSConfidence Val:  0.9881
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 19 Dec 2007 22:19:22 -0500
#
# XSConfidence Val:  0.9832
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: gbhatnag@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 19 Dec 2007 22:09:48 -0500
#
# XSConfidence Val:  0.9876
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: dlhaines@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 19 Dec 2007 20:06:00 -0500
#
# XSConfidence Val:  0.9853
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: jimeng@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 19 Dec 2007 18:24:30 -0500
#
# XSConfidence Val:  0.9845
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 19 Dec 2007 17:20:49 -0500
#
# XSConfidence Val:  0.9818
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 19 Dec 2007 17:16:42 -0500
#
# XSConfidence Val:  0.9829
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 19 Dec 2007 16:56:34 -0500
#
# XSConfidence Val:  0.9825
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Wed, 19 Dec 2007 16:54:49 -0500
#
# XSConfidence Val:  0.9824
#
# ----------------------------------------------------------------------------------------------
# ...
#
# XSConfidence Val:  0.9858
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Tue, 23 Oct 2007 12:17:02 -0400
#
# XSConfidence Val:  0.9899
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: chmaurer@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Tue, 23 Oct 2007 11:15:55 -0400
#
# XSConfidence Val:  0.9843
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: gjthomas@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Tue, 23 Oct 2007 09:20:28 -0400
#
# XSConfidence Val:  0.9788
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: gsilver@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Tue, 23 Oct 2007 09:12:19 -0400
#
# XSConfidence Val:  0.9804
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: ian@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Tue, 23 Oct 2007 09:10:07 -0400
#
# XSConfidence Val:  0.9847
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: ajpoland@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Tue, 23 Oct 2007 08:39:43 -0400
#
# XSConfidence Val:  0.9783
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: aaronz@vt.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Tue, 23 Oct 2007 07:41:51 -0400
#
# XSConfidence Val:  0.9845
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zach.thomas@txstate.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 22 Oct 2007 19:54:40 -0400
#
# XSConfidence Val:  0.983
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 22 Oct 2007 16:38:55 -0400
#
# XSConfidence Val:  0.9869
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 22 Oct 2007 15:45:32 -0400
#
# XSConfidence Val:  0.9875
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 22 Oct 2007 15:21:09 -0400
#
# XSConfidence Val:  0.9882
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: gjthomas@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 22 Oct 2007 14:51:54 -0400
#
# XSConfidence Val:  0.9784
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 22 Oct 2007 14:41:26 -0400
#
# XSConfidence Val:  0.9883
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 22 Oct 2007 14:38:03 -0400
#
# XSConfidence Val:  0.9782
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 22 Oct 2007 13:35:30 -0400
#
# XSConfidence Val:  0.9904
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 22 Oct 2007 13:31:37 -0400
#
# XSConfidence Val:  0.9818
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: aaronz@vt.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 22 Oct 2007 13:17:06 -0400
#
# XSConfidence Val:  0.9805
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: aaronz@vt.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Mon, 22 Oct 2007 13:16:54 -0400
#
# XSConfidence Val:  0.9788
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: ktsao@stanford.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 13:55:40 -0400
#
# XSConfidence Val:  0.9826
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: aaronz@vt.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 13:53:49 -0400
#
# XSConfidence Val:  0.9837
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: aaronz@vt.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 13:53:33 -0400
#
# XSConfidence Val:  0.9843
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: gsilver@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 13:33:54 -0400
#
# XSConfidence Val:  0.9872
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: gsilver@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 12:18:14 -0400
#
# XSConfidence Val:  0.9812
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: jzaremba@unicon.net
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 11:13:06 -0400
#
# XSConfidence Val:  0.9795
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: aaronz@vt.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 10:21:22 -0400
#
# XSConfidence Val:  0.985
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: dlhaines@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 10:13:55 -0400
#
# XSConfidence Val:  0.9859
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: dlhaines@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 10:11:46 -0400
#
# XSConfidence Val:  0.9846
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: dlhaines@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 10:06:30 -0400
#
# XSConfidence Val:  0.9863
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: ajpoland@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 09:22:36 -0400
#
# XSConfidence Val:  0.9803
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 09:21:20 -0400
#
# XSConfidence Val:  0.9912
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 09:20:25 -0400
#
# XSConfidence Val:  0.9896
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 09:16:38 -0400
#
# XSConfidence Val:  0.9907
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: dlhaines@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 08:58:14 -0400
#
# XSConfidence Val:  0.986
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: aaronz@vt.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 05:58:26 -0400
#
# XSConfidence Val:  0.9799
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: ktsao@stanford.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Fri, 19 Oct 2007 01:57:39 -0400
#
# XSConfidence Val:  0.9807
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: ian@caret.cam.ac.uk
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 18 Oct 2007 18:41:12 -0400
#
# XSConfidence Val:  0.9837
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 18 Oct 2007 16:06:59 -0400
#
# XSConfidence Val:  0.9862
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 18 Oct 2007 15:58:51 -0400
#
# XSConfidence Val:  0.9872
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: aaronz@vt.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 18 Oct 2007 13:12:28 -0400
#
# XSConfidence Val:  0.983
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: jzaremba@unicon.net
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 18 Oct 2007 12:15:19 -0400
#
# XSConfidence Val:  0.9769
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: dlhaines@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 18 Oct 2007 12:05:48 -0400
#
# XSConfidence Val:  0.9826
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: chmaurer@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 18 Oct 2007 11:49:30 -0400
#
# XSConfidence Val:  0.9861
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: zach.thomas@txstate.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 18 Oct 2007 11:31:49 -0400
#
# XSConfidence Val:  0.981
#
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# High Confidence value found:
# From: dlhaines@umich.edu
#
# To: source@collab.sakaiproject.org
#
# Date: Thu, 18 Oct 2007 10:53:54 -0400
#
# XSConfidence Val:  0.9836
#
# ----------------------------------------------------------------------------------------------
# Analysis of spam2.txt:
#
# ----------------------------------------------------------------------------------------------
# Emails with a spam value over 95%:  1003
# Percent of emails with a value over 95%:  55.784204671857616 %
# Number of values in the file:  1798
# Total of all the values in the file: 1606.7480999999987
# Avg spam confidence of spam2.txt:  0.8936307563959948
# Percent Avg spam confidence of spam2.txt: 89.36307563959947 %
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# #### **Exercise 5**
#
# ###### sections to reference: [list methods](https://www.py4e.com/html3/08-lists)
#
# Below are the lines of a program I wrote to add some things to a list of my favorite foods, sort the list, and then print them out in alphabetical order. The problem is that, when I was uploading this program to the supercomputer, my internet stopped working and my program's lines got all mixed up.
#
# Your task is this: rearrange the lines below so the program sorts and then prints the elements in my list of foods. When you've got the order all sorted out, put it in the code cell below. And thanks for your help!
#
# ```python
# my_fave_foods.sort()
# for food in my_fave_foods:
# my_fave_foods.append("asiago cheese")
# my_fave_foods = ["serrano peppers", "bananas", "apple pie", "veal", "smoked brisket"]
#     print(food)
# ```

# %%
my_fave_foods = ["serrano peppers", "bananas", "apple pie", "veal", "smoked brisket"]
my_fave_foods.append("asiago cheese")
my_fave_foods.sort()
for food in my_fave_foods:
    print(food)
# Out:
# apple pie
# asiago cheese
# bananas
# serrano peppers
# smoked brisket
# veal

# %% [markdown]
# #### **Exercise 6**
#
# ###### sections to reference: [lists](https://www.py4e.com/html3/08-lists)
#
# So, now that you're an expert in sorting lists of food, let's get a little bit more literary. `richard3.txt` contains the text of Richard's opening soliloquy from Shakespeare's play *Richard III*.
#
# You can watch a performance of it [here](https://www.youtube.com/watch?v=OfaVYn1v4jM), if you're interested.
#
# You're going to write a program that reads in the soliloquy from the file line by line. Then, using the `split` function, split each line into a list of words. Create a list to contain all of your words. Going word by word, check if the word is already in the list. If not, add it.
#
# Once you've gone through the whole file, sort the list of words in alphabetical order, and print it out.

# %%
fn = "C:/Users/tatty/0010Github/Python-Part3/richard3.txt"
file = open(fn)
sameWord = 0
words = []
for line in file.readlines():
    for word in line.split(" "):
        if word in words:
            sameWord+=1
        else:
            words.append(word)
            
words.sort()
for word in words:
    print(word)
print("Duplicate word count:", sameWord)
# Out:
# About
# And
# As
# But
# By
# Cheated
# Clarence
# Deformed
# Dive
# Edward
# Edward's
# G
#
# Grim
# Have
# He
# I
# In
# Into
# King
# Made
# Nor
# Now
# Of
# Our
# Plots
# That
# This
# To
# Unless
# Why
# York
#
# a
# adversaries
#
# against
# alarums
# all
# am
# ambling
# amorous
# an
# and
# are
# arms
# as
# at
# away
# barded
# bark
# be
# be
#
# before
# bosom
# bound
# breathing
# brother
# brows
# bruised
# buried
#
# by
# cannot
# capers
# chamber
#
# changed
# closely
# clouds
# comes
# court
# curtail'd
# dangerous
#
# day
# days
#
# deadly
# deep
# deformity
#
# delight
# delightful
# descant
# determined
# discontent
#
# dissembling
# dogs
# down
# dreadful
# dreams
#
# drunken
# entertain
# fair
# false
# fearful
# feature
# for
# fright
# front
#
# glass
#
# glorious
# half
# halt
# hate
# hath
# have
# heirs
# here
#
# his
# house
#
# hung
# idle
# if
# in
# inductions
# instead
# is
# just
#
# king
#
# lady's
# laid
# lamely
# lascivious
# libels
# looking
# lour'd
# love's
# lover
#
# lute
#
# made
# majesty
#
# marches
# me
# measures
#
# meetings
#
# merry
# mew'd
# mine
# monuments
#
# mounting
# murderer
# my
# nature
#
# nimbly
# no
# not
# now
# nymph
#
# ocean
# of
# on
# one
# other
#
# our
# own
# pass
# peace
#
# piping
# pleasing
# pleasures
# prophecies
# prophecy
# proportion
#
# prove
# rudely
# says
# scarce
# sent
# set
# shadow
# shall
# shaped
# should
# since
# smooth'd
# so
# soul
# souls
# spoken
# sportive
# spy
# stamp'd
# steeds
#
# stern
# strut
# subtle
# summer
# sun
# sun
#
# that
# the
# them
#
# therefore
# these
# this
# thoughts
# time
# time
#
# to
# treacherous
#
# tricks
#
# true
# unfashionable
#
# unfinish'd
# up
# up
#
# upon
# victorious
# villain
#
# visaged
# want
# wanton
# war
# weak
# well
# which
# winter
# with
# world
# wreaths
#
# wrinkled
# Duplicate word count: 94

# %% [markdown]
# #### **Exercise 7**
#
# ###### sections to reference: [dictionaries and files](https://www.py4e.com/html3/09-dictionaries)
#
# In the previous exercise, you just discarded words that were duplicates, but what if you wanted to count them?
#
# You're going to read in `richard3.txt` again, but this time use a *dictionary*. Iterate through the lines in the file and, for each word, if this is its first occurence, add the word as a *key* to the dictionary and the number "1" as a *value*. If the word exists in the dictionary, *add one* to its value.
#
# Then, print out your word-frequency dictionary.

# %%
fn = "C:/Users/tatty/0010Github/Python-Part3/richard3.txt"
file = open(fn)
sameWord = 0
words = dict()
#go over each line in the file
for line in file.readlines():
    #iterate over each word in the line
    for word in line.split(" "):
        #check if its already in the list
        if word in words:
            value = words[word]
            words[word] += value
        #if not add it to the list
        else:
            words[word] = 1
#print out the dict key value pairs
for word in words:
    print("Word:",word,":# used:", words[word])
# Out:
# Word: Now :# used: 2
# Word: is :# used: 1
# Word: the :# used: 4096
# Word: winter :# used: 1
# Word: of :# used: 512
# Word: our :# used: 4
# Word: discontent
#  :# used: 1
# Word: Made :# used: 1
# Word: glorious :# used: 1
# Word: summer :# used: 1
# Word: by :# used: 4
# Word: this :# used: 8
# Word: sun :# used: 1
# Word: York
#  :# used: 1
# Word: And :# used: 64
# Word: all :# used: 1
# Word: clouds :# used: 1
# Word: that :# used: 32
# Word: lour'd :# used: 1
# Word: upon :# used: 1
# Word: house
#  :# used: 1
# Word: In :# used: 2
# Word: deep :# used: 1
# Word: bosom :# used: 1
# Word: ocean :# used: 1
# Word: buried
#  :# used: 1
# Word: are :# used: 1
# Word: brows :# used: 1
# Word: bound :# used: 1
# Word: with :# used: 1
# Word: victorious :# used: 1
# Word: wreaths
#  :# used: 1
# Word: Our :# used: 4
# Word: bruised :# used: 1
# Word: arms :# used: 1
# Word: hung :# used: 1
# Word: up :# used: 1
# Word: for :# used: 2
# Word: monuments
#  :# used: 1
# Word: stern :# used: 1
# Word: alarums :# used: 1
# Word: changed :# used: 1
# Word: to :# used: 64
# Word: merry :# used: 1
# Word: meetings
#  :# used: 1
# Word: dreadful :# used: 1
# Word: marches :# used: 1
# Word: delightful :# used: 1
# Word: measures
#  :# used: 1
# Word: Grim :# used: 1
# Word: visaged :# used: 1
# Word: war :# used: 1
# Word: hath :# used: 1
# Word: smooth'd :# used: 1
# Word: his :# used: 1
# Word: wrinkled :# used: 1
# Word: front
#  :# used: 1
# Word: now :# used: 1
# Word: instead :# used: 1
# Word: mounting :# used: 1
# Word: barded :# used: 1
# Word: steeds
#  :# used: 1
# Word: To :# used: 16
# Word: fright :# used: 1
# Word: souls :# used: 1
# Word: fearful :# used: 1
# Word: adversaries
#  :# used: 1
# Word: He :# used: 1
# Word: capers :# used: 1
# Word: nimbly :# used: 1
# Word: in :# used: 4
# Word: a :# used: 32
# Word: lady's :# used: 1
# Word: chamber
#  :# used: 1
# Word: lascivious :# used: 1
# Word: pleasing :# used: 1
# Word: lute
#  :# used: 1
# Word: But :# used: 1
# Word: I :# used: 256
# Word: am :# used: 16
# Word: not :# used: 1
# Word: shaped :# used: 1
# Word: sportive :# used: 1
# Word: tricks
#  :# used: 1
# Word: Nor :# used: 1
# Word: made :# used: 2
# Word: court :# used: 1
# Word: an :# used: 1
# Word: amorous :# used: 1
# Word: looking :# used: 1
# Word: glass
#  :# used: 1
# Word: rudely :# used: 1
# Word: stamp'd :# used: 1
# Word: and :# used: 32
# Word: want :# used: 1
# Word: love's :# used: 1
# Word: majesty
#  :# used: 1
# Word: strut :# used: 1
# Word: before :# used: 2
# Word: wanton :# used: 1
# Word: ambling :# used: 1
# Word: nymph
#  :# used: 1
# Word: curtail'd :# used: 1
# Word: fair :# used: 2
# Word: proportion
#  :# used: 1
# Word: Cheated :# used: 1
# Word: feature :# used: 1
# Word: dissembling :# used: 1
# Word: nature
#  :# used: 1
# Word: Deformed :# used: 1
# Word: unfinish'd :# used: 1
# Word: sent :# used: 1
# Word: my :# used: 8
# Word: time
#  :# used: 2
# Word: Into :# used: 1
# Word: breathing :# used: 1
# Word: world :# used: 1
# Word: scarce :# used: 1
# Word: half :# used: 1
# Word: up
#  :# used: 2
# Word: so :# used: 1
# Word: lamely :# used: 1
# Word: unfashionable
#  :# used: 1
# Word: That :# used: 1
# Word: dogs :# used: 1
# Word: bark :# used: 1
# Word: at :# used: 1
# Word: me :# used: 1
# Word: as :# used: 2
# Word: halt :# used: 1
# Word: them
#  :# used: 1
# Word: Why :# used: 1
# Word: weak :# used: 1
# Word: piping :# used: 1
# Word: time :# used: 1
# Word: peace
#  :# used: 1
# Word: Have :# used: 1
# Word: no :# used: 1
# Word: delight :# used: 1
# Word: pass :# used: 1
# Word: away :# used: 1
# Word: Unless :# used: 1
# Word: spy :# used: 1
# Word: shadow :# used: 1
# Word: sun
#  :# used: 1
# Word: descant :# used: 1
# Word: on :# used: 1
# Word: mine :# used: 1
# Word: own :# used: 1
# Word: deformity
#  :# used: 1
# Word: therefore :# used: 1
# Word: since :# used: 1
# Word: cannot :# used: 1
# Word: prove :# used: 2
# Word: lover
#  :# used: 1
# Word: entertain :# used: 1
# Word: these :# used: 2
# Word: well :# used: 1
# Word: spoken :# used: 1
# Word: days
#  :# used: 2
# Word: determined :# used: 1
# Word: villain
#  :# used: 1
# Word: hate :# used: 2
# Word: idle :# used: 1
# Word: pleasures :# used: 1
# Word: Plots :# used: 1
# Word: have :# used: 1
# Word: laid :# used: 1
# Word: inductions :# used: 1
# Word: dangerous
#  :# used: 1
# Word: By :# used: 1
# Word: drunken :# used: 1
# Word: prophecies :# used: 1
# Word: libels :# used: 1
# Word: dreams
#  :# used: 1
# Word: set :# used: 1
# Word: brother :# used: 1
# Word: Clarence :# used: 4
# Word: king
#  :# used: 1
# Word: deadly :# used: 1
# Word: one :# used: 1
# Word: against :# used: 1
# Word: other
#  :# used: 1
# Word: if :# used: 1
# Word: King :# used: 1
# Word: Edward :# used: 1
# Word: be :# used: 2
# Word: true :# used: 1
# Word: just
#  :# used: 1
# Word: As :# used: 1
# Word: subtle :# used: 1
# Word: false :# used: 1
# Word: treacherous
#  :# used: 1
# Word: This :# used: 1
# Word: day :# used: 1
# Word: should :# used: 1
# Word: closely :# used: 1
# Word: mew'd :# used: 1
# Word: About :# used: 1
# Word: prophecy :# used: 1
# Word: which :# used: 1
# Word: says :# used: 1
# Word: G
#  :# used: 1
# Word: Of :# used: 1
# Word: Edward's :# used: 1
# Word: heirs :# used: 1
# Word: murderer :# used: 1
# Word: shall :# used: 1
# Word: be
#  :# used: 1
# Word: Dive :# used: 1
# Word: thoughts :# used: 1
# Word: down :# used: 1
# Word: soul :# used: 1
# Word: here
#  :# used: 1
# Word: comes :# used: 1
